# %%
import pandas as pd   #for reading csv data
import matplotlib.pyplot as plt

# %%
#load the data from the csv file to the jupyter notebook
data=pd.read_csv('/Users/delta/python/unemployment_analysis.csv')

# %%
#clear the unwanted data
data.drop(columns=["Country Code"], inplace=True)
data.drop(columns=["1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007"],inplace=True)

#display the data to check the drop
data
# Out:
#                     Country Name   2008   2009   2010   2011   2012   2013  \
# 0    Africa Eastern and Southern   6.27   6.32   6.87   6.75   6.56   6.45
# 1                    Afghanistan  11.09  11.31  11.35  11.05  11.34  11.19
# 2     Africa Western and Central   4.60   4.58   4.55   4.55   4.64   4.41
# 3                         Angola   3.79   3.78   9.43   7.36   7.35   7.37
# 4                        Albania  13.06  13.67  14.09  13.48  13.38  15.87
# ..                           ...    ...    ...    ...    ...    ...    ...
# 230                        Samoa   5.58   5.83   5.73   5.68   8.75   8.67
# 231                  Yemen, Rep.  12.62  12.75  12.83  13.23  13.17  13.27
# 232                 South Africa  22.41  23.52  24.68  24.64  24.73  24.56
# 233                       Zambia   7.93  10.56  13.19  10.55   7.85   8.61
# 234                     Zimbabwe   5.01   5.08   5.21   5.37   5.15   4.98
#
#       2014   2015   2016   2017   2018   2019   2020   2021
# ...

# %%
#modifying data for better understanding
data = data.set_index("Country Name").transpose()
data.index.names = ["Year"]
data.head()
# Out:
# Country Name  Africa Eastern and Southern  Afghanistan  \
# Year
# 2008                                 6.27        11.09
# 2009                                 6.32        11.31
# 2010                                 6.87        11.35
# 2011                                 6.75        11.05
# 2012                                 6.56        11.34
#
# Country Name  Africa Western and Central  Angola  Albania  Arab World  \
# Year
# 2008                                4.60    3.79    13.06        9.72
# 2009                                4.58    3.78    13.67        9.33
# 2010                                4.55    9.43    14.09        9.40
# 2011                                4.55    7.36    13.48       10.48
# 2012                                4.64    7.35    13.38       10.66
#
# Country Name  United Arab Emirates  Argentina  Armenia  Australia  ...  \
# Year                                                               ...
# ...

# %%
#Creating a dataFrame with few selected countries
df=data.loc[:,["Afghanistan","Australia","United States","Pakistan","India","Vietnam"]]
print(df)
# Out:
# Country Name  Afghanistan  Australia  United States  Pakistan  India  Vietnam
# Year
# 2008                11.09       4.23           5.78      0.42   5.41     1.93
# 2009                11.31       5.56           9.25      0.54   5.54     1.74
# 2010                11.35       5.21           9.63      0.65   5.55     1.11
# 2011                11.05       5.08           8.95      0.80   5.43     1.00
# 2012                11.34       5.22           8.07      1.85   5.41     1.03
# 2013                11.19       5.66           7.37      2.95   5.42     1.32
# 2014                11.14       6.08           6.17      1.83   5.44     1.26
# 2015                11.13       6.05           5.28      3.57   5.43     1.85
# 2016                11.16       5.71           4.87      3.78   5.42     1.85
# 2017                11.18       5.59           4.36      3.92   5.36     1.87
# 2018                11.15       5.30           3.90      4.08   5.33     1.16
# ...

# %%
#plot the graph for unemployment rate from 2008 to 2021 for the selected coutries
df["0":"5"].plot()
plt.show()

# %%
#we can see that there is a rise in the unemployment rate between 2019 and 2021 in all the coutries
