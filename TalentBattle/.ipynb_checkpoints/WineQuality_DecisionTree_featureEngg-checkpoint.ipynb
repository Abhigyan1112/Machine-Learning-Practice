# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/Users/delta/ML/wine_quality/winequality-red.csv',delimiter=';')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
X=df.drop(columns=['quality'])
Y=df['quality']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
print(X_train.shape,
X_test.shape,
Y_train.shape,
Y_test.shape)
# Out:
# (1119, 11) (480, 11) (1119,) (480,)

# %%
clf=DecisionTreeClassifier(random_state=42)

# %%
clf.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
Y_pred=clf.predict(X_test)

# %%
acc_score=accuracy_score(Y_test,Y_pred)
print(acc_score)
# Out:
# 0.5729166666666666

# %%
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.07      0.06      0.06        17
#            5       0.66      0.65      0.65       195
#            6       0.57      0.60      0.59       200
#            7       0.46      0.43      0.44        61
#            8       0.33      0.17      0.22         6
#
#     accuracy                           0.57       480
#    macro avg       0.35      0.32      0.33       480
# weighted avg       0.57      0.57      0.57       480

# %%
print(confusion_matrix(Y_test,Y_pred))
# Out:
# [[  0   0   1   0   0   0]
#  [  0   1  10   5   1   0]
#  [  1   8 126  58   2   0]
#  [  0   5  48 121  26   0]
#  [  0   1   6  26  26   2]
#  [  0   0   0   3   2   1]]

# %%
plt.figure(figsize=(20,10))
plot_tree(clf,feature_names=X.columns,class_names=[str(c) for c in sorted(Y.unique())],filled=True)
# Out:
# [Text(0.6076337321232124, 0.975, 'alcohol <= 10.525\ngini = 0.642\nsamples = 1119\nvalue = [9, 36, 486, 438, 138, 12]\nclass = 5'),
#  Text(0.40738792629262927, 0.925, 'total sulfur dioxide <= 98.5\ngini = 0.537\nsamples = 692\nvalue = [6.0, 25.0, 415.0, 219.0, 25.0, 2.0]\nclass = 5'),
#  Text(0.244258800880088, 0.875, 'sulphates <= 0.575\ngini = 0.567\nsamples = 602\nvalue = [6, 24, 331, 215, 24, 2]\nclass = 5'),
#  Text(0.09075907590759076, 0.825, 'alcohol <= 9.75\ngini = 0.5\nsamples = 234\nvalue = [4, 18, 156, 52, 4, 0]\nclass = 5'),
#  Text(0.04576457645764576, 0.775, 'pH <= 3.54\ngini = 0.406\nsamples = 148\nvalue = [2, 10, 111, 24, 1, 0]\nclass = 5'),
#  Text(0.042244224422442245, 0.725, 'residual sugar <= 4.4\ngini = 0.388\nsamples = 145\nvalue = [2, 10, 111, 21, 1, 0]\nclass = 5'),
#  Text(0.028162816281628162, 0.675, 'alcohol <= 9.075\ngini = 0.354\nsamples = 139\nvalue = [2, 9, 110, 17, 1, 0]\nclass = 5'),
#  Text(0.014081408140814081, 0.625, 'residual sugar <= 2.05\ngini = 0.716\nsamples = 9\nvalue = [1, 2, 3, 3, 0, 0]\nclass = 5'),
#  Text(0.0070407040704070405, 0.575, 'density <= 0.996\ngini = 0.48\nsamples = 5\nvalue = [0, 2, 3, 0, 0, 0]\nclass = 5'),
#  Text(0.0035203520352035203, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.010561056105610561, 0.525, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(0.021122112211221122, 0.575, 'density <= 1.001\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 0, 3, 0, 0]\nclass = 6'),
#  Text(0.0176017601760176, 0.525, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]\nclass = 6'),
#  Text(0.024642464246424644, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]\nclass = 3'),
#  Text(0.042244224422442245, 0.625, 'volatile acidity <= 0.275\ngini = 0.308\nsamples = 130\nvalue = [1, 7, 107, 14, 1, 0]\nclass = 5'),
#  Text(0.0352035203520352, 0.575, 'alcohol <= 9.35\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]\nclass = 4'),
#  Text(0.031683168316831684, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.03872387238723873, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.04928492849284929, 0.575, 'volatile acidity <= 0.972\ngini = 0.289\nsamples = 128\nvalue = [1, 6, 107, 13, 1, 0]\nclass = 5'),
#  Text(0.04576457645764576, 0.525, 'fixed acidity <= 7.05\ngini = 0.277\nsamples = 127\nvalue = [0, 6, 107, 13, 1, 0]\nclass = 5'),
#  Text(0.03454345434543454, 0.475, 'citric acid <= 0.28\ngini = 0.43\nsamples = 16\nvalue = [0, 0, 11, 5, 0, 0]\nclass = 5'),
#  Text(0.031023102310231022, 0.425, 'total sulfur dioxide <= 83.25\ngini = 0.337\nsamples = 14\nvalue = [0, 0, 11, 3, 0, 0]\nclass = 5'),
#  Text(0.027502750275027504, 0.375, 'residual sugar <= 1.9\ngini = 0.26\nsamples = 13\nvalue = [0, 0, 11, 2, 0, 0]\nclass = 5'),
#  Text(0.023982398239823982, 0.325, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]\nclass = 5'),
#  Text(0.031023102310231022, 0.325, 'volatile acidity <= 0.57\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]\nclass = 5'),
#  Text(0.027502750275027504, 0.275, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.03454345434543454, 0.275, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(0.03454345434543454, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.03806380638063806, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.05698569856985698, 0.475, 'fixed acidity <= 7.75\ngini = 0.244\nsamples = 111\nvalue = [0, 6, 96, 8, 1, 0]\nclass = 5'),
#  Text(0.045104510451045104, 0.425, 'total sulfur dioxide <= 12.5\ngini = 0.04\nsamples = 49\nvalue = [0.0, 1.0, 48.0, 0.0, 0.0, 0.0]\nclass = 5'),
#  Text(0.041584158415841586, 0.375, 'alcohol <= 9.55\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]\nclass = 4'),
#  Text(0.03806380638063806, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.045104510451045104, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.04862486248624862, 0.375, 'gini = 0.0\nsamples = 47\nvalue = [0, 0, 47, 0, 0, 0]\nclass = 5'),
#  Text(0.06886688668866886, 0.425, 'volatile acidity <= 0.657\ngini = 0.377\nsamples = 62\nvalue = [0, 5, 48, 8, 1, 0]\nclass = 5'),
#  Text(0.055665566556655666, 0.375, 'citric acid <= 0.03\ngini = 0.234\nsamples = 39\nvalue = [0, 2, 34, 2, 1, 0]\nclass = 5'),
#  Text(0.05214521452145215, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.059185918591859184, 0.325, 'density <= 0.996\ngini = 0.194\nsamples = 38\nvalue = [0, 2, 34, 2, 0, 0]\nclass = 5'),
#  Text(0.055665566556655666, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.0627062706270627, 0.275, 'pH <= 3.365\ngini = 0.152\nsamples = 37\nvalue = [0, 2, 34, 1, 0, 0]\nclass = 5'),
#  Text(0.0539053905390539, 0.225, 'chlorides <= 0.072\ngini = 0.108\nsamples = 35\nvalue = [0, 2, 33, 0, 0, 0]\nclass = 5'),
#  Text(0.04686468646864687, 0.175, 'residual sugar <= 1.85\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]\nclass = 4'),
#  Text(0.04334433443344334, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.050385038503850385, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.060946094609460946, 0.175, 'alcohol <= 9.35\ngini = 0.059\nsamples = 33\nvalue = [0, 1, 32, 0, 0, 0]\nclass = 5'),
#  Text(0.05742574257425743, 0.125, 'alcohol <= 9.25\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 5, 0, 0, 0]\nclass = 5'),
#  Text(0.0539053905390539, 0.075, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]\nclass = 5'),
#  Text(0.060946094609460946, 0.075, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.06446644664466447, 0.125, 'gini = 0.0\nsamples = 27\nvalue = [0, 0, 27, 0, 0, 0]\nclass = 5'),
#  Text(0.07150715071507151, 0.225, 'density <= 0.998\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]\nclass = 5'),
#  Text(0.06798679867986798, 0.175, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.07502750275027503, 0.175, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.08206820682068207, 0.375, 'sulphates <= 0.465\ngini = 0.544\nsamples = 23\nvalue = [0, 3, 14, 6, 0, 0]\nclass = 5'),
#  Text(0.07326732673267326, 0.325, 'pH <= 3.28\ngini = 0.375\nsamples = 4\nvalue = [0, 3, 1, 0, 0, 0]\nclass = 4'),
#  Text(0.06974697469746975, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.07678767876787679, 0.275, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.09086908690869087, 0.325, 'volatile acidity <= 0.718\ngini = 0.432\nsamples = 19\nvalue = [0, 0, 13, 6, 0, 0]\nclass = 5'),
#  Text(0.08382838283828382, 0.275, 'chlorides <= 0.082\ngini = 0.49\nsamples = 7\nvalue = [0, 0, 3, 4, 0, 0]\nclass = 6'),
#  Text(0.08030803080308031, 0.225, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]\nclass = 6'),
#  Text(0.08734873487348735, 0.225, 'citric acid <= 0.105\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]\nclass = 5'),
#  Text(0.08382838283828382, 0.175, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.09086908690869087, 0.175, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(0.09790979097909791, 0.275, 'sulphates <= 0.495\ngini = 0.278\nsamples = 12\nvalue = [0, 0, 10, 2, 0, 0]\nclass = 5'),
#  Text(0.09438943894389439, 0.225, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.10143014301430144, 0.225, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]\nclass = 5'),
#  Text(0.052805280528052806, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]\nclass = 3'),
#  Text(0.056325632563256324, 0.675, 'citric acid <= 0.195\ngini = 0.5\nsamples = 6\nvalue = [0, 1, 1, 4, 0, 0]\nclass = 6'),
#  Text(0.052805280528052806, 0.625, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]\nclass = 6'),
#  Text(0.05984598459845985, 0.625, 'chlorides <= 0.071\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]\nclass = 4'),
#  Text(0.056325632563256324, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.06336633663366337, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.04928492849284929, 0.725, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]\nclass = 6'),
#  Text(0.13575357535753577, 0.775, 'volatile acidity <= 0.345\ngini = 0.61\nsamples = 86\nvalue = [2.0, 8.0, 45.0, 28.0, 3.0, 0.0]\nclass = 5'),
#  Text(0.13223322332233223, 0.725, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]\nclass = 6'),
#  Text(0.13927392739273928, 0.725, 'density <= 0.994\ngini = 0.596\nsamples = 80\nvalue = [2, 8, 45, 22, 3, 0]\nclass = 5'),
#  Text(0.13575357535753577, 0.675, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.1427942794279428, 0.675, 'free sulfur dioxide <= 29.0\ngini = 0.57\nsamples = 77\nvalue = [2.0, 5.0, 45.0, 22.0, 3.0, 0.0]\nclass = 5'),
#  Text(0.13927392739273928, 0.625, 'sulphates <= 0.535\ngini = 0.557\nsamples = 74\nvalue = [2, 5, 45, 19, 3, 0]\nclass = 5'),
#  Text(0.11023102310231023, 0.575, 'residual sugar <= 1.25\ngini = 0.438\nsamples = 41\nvalue = [2, 2, 30, 6, 1, 0]\nclass = 5'),
#  Text(0.10319031903190319, 0.525, 'fixed acidity <= 7.05\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 0, 1, 0]\nclass = 3'),
#  Text(0.09966996699669967, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]\nclass = 3'),
#  Text(0.10671067106710672, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.11727172717271728, 0.525, 'density <= 0.996\ngini = 0.381\nsamples = 39\nvalue = [1, 2, 30, 6, 0, 0]\nclass = 5'),
#  Text(0.11375137513751375, 0.475, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 16, 0, 0, 0]\nclass = 5'),
#  Text(0.12079207920792079, 0.475, 'residual sugar <= 1.85\ngini = 0.552\nsamples = 23\nvalue = [1, 2, 14, 6, 0, 0]\nclass = 5'),
#  Text(0.11727172717271728, 0.425, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]\nclass = 6'),
#  Text(0.12431243124312431, 0.425, 'volatile acidity <= 0.873\ngini = 0.475\nsamples = 20\nvalue = [1, 2, 14, 3, 0, 0]\nclass = 5'),
#  Text(0.11551155115511551, 0.375, 'density <= 0.996\ngini = 0.364\nsamples = 18\nvalue = [0, 1, 14, 3, 0, 0]\nclass = 5'),
#  Text(0.10847084708470847, 0.325, 'fixed acidity <= 8.25\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]\nclass = 6'),
#  Text(0.10495049504950495, 0.275, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.111991199119912, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.12255225522552256, 0.325, 'total sulfur dioxide <= 60.0\ngini = 0.24\nsamples = 15\nvalue = [0, 1, 13, 1, 0, 0]\nclass = 5'),
#  Text(0.11903190319031903, 0.275, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0, 0]\nclass = 5'),
#  Text(0.12607260726072608, 0.275, 'alcohol <= 9.85\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 2, 1, 0, 0]\nclass = 5'),
#  Text(0.12255225522552256, 0.225, 'chlorides <= 0.08\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]\nclass = 4'),
#  Text(0.11903190319031903, 0.175, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.12607260726072608, 0.175, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.1295929592959296, 0.225, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 5'),
#  Text(0.1331133113311331, 0.375, 'volatile acidity <= 0.895\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0, 0, 0]\nclass = 3'),
#  Text(0.1295929592959296, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]\nclass = 3'),
#  Text(0.13663366336633664, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.16831683168316833, 0.575, 'chlorides <= 0.082\ngini = 0.626\nsamples = 33\nvalue = [0, 3, 15, 13, 2, 0]\nclass = 5'),
#  Text(0.15423542354235423, 0.525, 'chlorides <= 0.069\ngini = 0.418\nsamples = 15\nvalue = [0, 1, 11, 3, 0, 0]\nclass = 5'),
#  Text(0.1471947194719472, 0.475, 'fixed acidity <= 7.45\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 1, 2, 0, 0]\nclass = 6'),
#  Text(0.14367436743674367, 0.425, 'density <= 0.996\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]\nclass = 4'),
#  Text(0.14015401540154016, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.1471947194719472, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.15071507150715072, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.16127612761276128, 0.475, 'density <= 0.999\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 10, 1, 0, 0]\nclass = 5'),
#  Text(0.15775577557755777, 0.425, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]\nclass = 5'),
#  Text(0.1647964796479648, 0.425, 'pH <= 3.14\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]\nclass = 5'),
#  Text(0.16127612761276128, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.16831683168316833, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.1823982398239824, 0.525, 'density <= 0.997\ngini = 0.617\nsamples = 18\nvalue = [0, 2, 4, 10, 2, 0]\nclass = 6'),
#  Text(0.17535753575357535, 0.475, 'citric acid <= 0.015\ngini = 0.278\nsamples = 12\nvalue = [0, 0, 0, 10, 2, 0]\nclass = 6'),
#  Text(0.17183718371837184, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]\nclass = 7'),
#  Text(0.1788778877887789, 0.425, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]\nclass = 6'),
#  Text(0.18943894389438945, 0.475, 'residual sugar <= 2.2\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4, 0, 0, 0]\nclass = 5'),
#  Text(0.1859185918591859, 0.425, 'free sulfur dioxide <= 17.5\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0, 0, 0]\nclass = 4'),
#  Text(0.1823982398239824, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.18943894389438945, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.19295929592959296, 0.425, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(0.14631463146314633, 0.625, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]\nclass = 6'),
#  Text(0.39775852585258525, 0.825, 'volatile acidity <= 0.548\ngini = 0.574\nsamples = 368\nvalue = [2, 6, 175, 163, 20, 2]\nclass = 5'),
#  Text(0.2893014301430143, 0.775, 'sulphates <= 0.665\ngini = 0.584\nsamples = 205\nvalue = [1, 3, 76, 107, 16, 2]\nclass = 6'),
#  Text(0.23256325632563257, 0.725, 'chlorides <= 0.165\ngini = 0.528\nsamples = 97\nvalue = [0.0, 0.0, 50.0, 44.0, 3.0, 0.0]\nclass = 5'),
#  Text(0.22904290429042903, 0.675, 'chlorides <= 0.098\ngini = 0.525\nsamples = 93\nvalue = [0, 0, 50, 40, 3, 0]\nclass = 5'),
#  Text(0.22552255225522552, 0.625, 'free sulfur dioxide <= 4.5\ngini = 0.532\nsamples = 86\nvalue = [0, 0, 43, 40, 3, 0]\nclass = 5'),
#  Text(0.222002200220022, 0.575, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]\nclass = 5'),
#  Text(0.22904290429042903, 0.575, 'density <= 0.998\ngini = 0.535\nsamples = 81\nvalue = [0, 0, 38, 40, 3, 0]\nclass = 6'),
#  Text(0.2088008800880088, 0.525, 'free sulfur dioxide <= 8.5\ngini = 0.509\nsamples = 50\nvalue = [0, 0, 18, 30, 2, 0]\nclass = 6'),
#  Text(0.20528052805280528, 0.475, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]\nclass = 6'),
#  Text(0.21232123212321233, 0.475, 'volatile acidity <= 0.405\ngini = 0.545\nsamples = 40\nvalue = [0, 0, 18, 20, 2, 0]\nclass = 6'),
#  Text(0.2, 0.425, 'pH <= 3.3\ngini = 0.375\nsamples = 12\nvalue = [0, 0, 3, 9, 0, 0]\nclass = 6'),
#  Text(0.19647964796479647, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 5'),
#  Text(0.20352035203520352, 0.375, 'chlorides <= 0.072\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 1, 9, 0, 0]\nclass = 6'),
#  Text(0.2, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.20704070407040703, 0.325, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]\nclass = 6'),
#  Text(0.22464246424642464, 0.425, 'density <= 0.996\ngini = 0.554\nsamples = 28\nvalue = [0, 0, 15, 11, 2, 0]\nclass = 5'),
#  Text(0.2176017601760176, 0.375, 'total sulfur dioxide <= 80.5\ngini = 0.32\nsamples = 10\nvalue = [0, 0, 2, 8, 0, 0]\nclass = 6'),
#  Text(0.21408140814081408, 0.325, 'volatile acidity <= 0.42\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 1, 8, 0, 0]\nclass = 6'),
#  Text(0.21056105610561057, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.2176017601760176, 0.275, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]\nclass = 6'),
#  Text(0.22112211221122113, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.2316831683168317, 0.375, 'fixed acidity <= 7.95\ngini = 0.438\nsamples = 18\nvalue = [0, 0, 13, 3, 2, 0]\nclass = 5'),
#  Text(0.22816281628162816, 0.325, 'pH <= 3.385\ngini = 0.231\nsamples = 15\nvalue = [0, 0, 13, 0, 2, 0]\nclass = 5'),
#  Text(0.22464246424642464, 0.275, 'residual sugar <= 2.45\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 2, 0]\nclass = 7'),
#  Text(0.22112211221122113, 0.225, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]\nclass = 7'),
#  Text(0.22816281628162816, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.2316831683168317, 0.275, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0, 0, 0]\nclass = 5'),
#  Text(0.2352035203520352, 0.325, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]\nclass = 6'),
#  Text(0.24928492849284928, 0.525, 'residual sugar <= 1.95\ngini = 0.479\nsamples = 31\nvalue = [0, 0, 20, 10, 1, 0]\nclass = 5'),
#  Text(0.24224422442244226, 0.475, 'fixed acidity <= 7.65\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]\nclass = 6'),
#  Text(0.23872387238723872, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.24576457645764577, 0.425, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]\nclass = 6'),
#  Text(0.2563256325632563, 0.475, 'free sulfur dioxide <= 25.0\ngini = 0.411\nsamples = 26\nvalue = [0, 0, 19, 6, 1, 0]\nclass = 5'),
#  Text(0.2528052805280528, 0.425, 'pH <= 3.13\ngini = 0.344\nsamples = 24\nvalue = [0, 0, 19, 4, 1, 0]\nclass = 5'),
#  Text(0.24576457645764577, 0.375, 'chlorides <= 0.078\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 3, 3, 0, 0]\nclass = 5'),
#  Text(0.24224422442244226, 0.325, 'volatile acidity <= 0.515\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]\nclass = 5'),
#  Text(0.23872387238723872, 0.275, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(0.24576457645764577, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.24928492849284928, 0.325, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.25984598459845987, 0.375, 'total sulfur dioxide <= 85.0\ngini = 0.204\nsamples = 18\nvalue = [0, 0, 16, 1, 1, 0]\nclass = 5'),
#  Text(0.2563256325632563, 0.325, 'sulphates <= 0.605\ngini = 0.111\nsamples = 17\nvalue = [0, 0, 16, 0, 1, 0]\nclass = 5'),
#  Text(0.2528052805280528, 0.275, 'volatile acidity <= 0.495\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 0, 1, 0]\nclass = 5'),
#  Text(0.24928492849284928, 0.225, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 5'),
#  Text(0.2563256325632563, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.25984598459845987, 0.275, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 14, 0, 0, 0]\nclass = 5'),
#  Text(0.2633663366336634, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.25984598459845987, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.23256325632563257, 0.625, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]\nclass = 5'),
#  Text(0.23608360836083608, 0.675, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]\nclass = 6'),
#  Text(0.346039603960396, 0.725, 'chlorides <= 0.342\ngini = 0.586\nsamples = 108\nvalue = [1.0, 3.0, 26.0, 63.0, 13.0, 2.0]\nclass = 6'),
#  Text(0.3204620462046205, 0.675, 'total sulfur dioxide <= 59.5\ngini = 0.557\nsamples = 102\nvalue = [1, 2, 22, 63, 12, 2]\nclass = 6'),
#  Text(0.2851485148514851, 0.625, 'pH <= 3.025\ngini = 0.514\nsamples = 81\nvalue = [1, 1, 12, 54, 11, 2]\nclass = 6'),
#  Text(0.2633663366336634, 0.575, 'fixed acidity <= 12.25\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 1, 0, 2, 1]\nclass = 7'),
#  Text(0.25984598459845987, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]\nclass = 7'),
#  Text(0.2668866886688669, 0.525, 'residual sugar <= 2.1\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 0, 1]\nclass = 5'),
#  Text(0.2633663366336634, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.2704070407040704, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]\nclass = 8'),
#  Text(0.3069306930693069, 0.575, 'density <= 0.997\ngini = 0.474\nsamples = 77\nvalue = [1, 1, 11, 54, 9, 1]\nclass = 6'),
#  Text(0.280968096809681, 0.525, 'alcohol <= 9.65\ngini = 0.649\nsamples = 15\nvalue = [0, 0, 5, 7, 2, 1]\nclass = 6'),
#  Text(0.2774477447744774, 0.475, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]\nclass = 5'),
#  Text(0.2844884488448845, 0.475, 'volatile acidity <= 0.41\ngini = 0.545\nsamples = 11\nvalue = [0, 0, 1, 7, 2, 1]\nclass = 6'),
#  Text(0.280968096809681, 0.425, 'citric acid <= 0.245\ngini = 0.72\nsamples = 5\nvalue = [0, 0, 1, 1, 2, 1]\nclass = 7'),
#  Text(0.2774477447744774, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]\nclass = 7'),
#  Text(0.2844884488448845, 0.375, 'free sulfur dioxide <= 4.0\ngini = 0.667\nsamples = 3\nvalue = [0, 0, 1, 1, 0, 1]\nclass = 5'),
#  Text(0.280968096809681, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]\nclass = 8'),
#  Text(0.288008800880088, 0.325, 'citric acid <= 0.47\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]\nclass = 5'),
#  Text(0.2844884488448845, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.2915291529152915, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.288008800880088, 0.425, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]\nclass = 6'),
#  Text(0.3328932893289329, 0.525, 'residual sugar <= 4.8\ngini = 0.403\nsamples = 62\nvalue = [1, 1, 6, 47, 7, 0]\nclass = 6'),
#  Text(0.32585258525852584, 0.475, 'fixed acidity <= 14.35\ngini = 0.374\nsamples = 59\nvalue = [1, 1, 6, 46, 5, 0]\nclass = 6'),
#  Text(0.32233223322332233, 0.425, 'free sulfur dioxide <= 32.5\ngini = 0.355\nsamples = 58\nvalue = [1, 1, 6, 46, 4, 0]\nclass = 6'),
#  Text(0.3108910891089109, 0.375, 'chlorides <= 0.058\ngini = 0.313\nsamples = 55\nvalue = [0, 0, 6, 45, 4, 0]\nclass = 6'),
#  Text(0.3020902090209021, 0.325, 'sulphates <= 0.805\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 0, 2, 2, 0]\nclass = 6'),
#  Text(0.29856985698569855, 0.275, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.3056105610561056, 0.275, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]\nclass = 7'),
#  Text(0.31969196919691967, 0.325, 'alcohol <= 9.75\ngini = 0.274\nsamples = 51\nvalue = [0, 0, 6, 43, 2, 0]\nclass = 6'),
#  Text(0.31265126512651265, 0.275, 'total sulfur dioxide <= 16.5\ngini = 0.39\nsamples = 28\nvalue = [0, 0, 6, 21, 1, 0]\nclass = 6'),
#  Text(0.30913091309130913, 0.225, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(0.31617161716171616, 0.225, 'density <= 0.997\ngini = 0.278\nsamples = 25\nvalue = [0, 0, 3, 21, 1, 0]\nclass = 6'),
#  Text(0.31265126512651265, 0.175, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.31969196919691967, 0.175, 'chlorides <= 0.085\ngini = 0.219\nsamples = 24\nvalue = [0, 0, 3, 21, 0, 0]\nclass = 6'),
#  Text(0.31617161716171616, 0.125, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 0, 13, 0, 0]\nclass = 6'),
#  Text(0.32321232123212323, 0.125, 'total sulfur dioxide <= 35.0\ngini = 0.397\nsamples = 11\nvalue = [0, 0, 3, 8, 0, 0]\nclass = 6'),
#  Text(0.31969196919691967, 0.075, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 5'),
#  Text(0.32673267326732675, 0.075, 'fixed acidity <= 7.75\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 1, 8, 0, 0]\nclass = 6'),
#  Text(0.32321232123212323, 0.025, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.33025302530253026, 0.025, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]\nclass = 6'),
#  Text(0.32673267326732675, 0.275, 'total sulfur dioxide <= 46.5\ngini = 0.083\nsamples = 23\nvalue = [0, 0, 0, 22, 1, 0]\nclass = 6'),
#  Text(0.32321232123212323, 0.225, 'gini = 0.0\nsamples = 18\nvalue = [0, 0, 0, 18, 0, 0]\nclass = 6'),
#  Text(0.33025302530253026, 0.225, 'total sulfur dioxide <= 50.0\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 4, 1, 0]\nclass = 6'),
#  Text(0.32673267326732675, 0.175, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.33377337733773377, 0.175, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]\nclass = 6'),
#  Text(0.33377337733773377, 0.375, 'total sulfur dioxide <= 49.5\ngini = 0.667\nsamples = 3\nvalue = [1, 1, 0, 1, 0, 0]\nclass = 3'),
#  Text(0.33025302530253026, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]\nclass = 3'),
#  Text(0.3372937293729373, 0.325, 'chlorides <= 0.108\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]\nclass = 4'),
#  Text(0.33377337733773377, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.3408140814081408, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.32937293729372935, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.33993399339933994, 0.475, 'pH <= 3.27\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]\nclass = 7'),
#  Text(0.33641364136413643, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.34345434543454345, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]\nclass = 7'),
#  Text(0.3557755775577558, 0.625, 'sulphates <= 0.715\ngini = 0.585\nsamples = 21\nvalue = [0, 1, 10, 9, 1, 0]\nclass = 5'),
#  Text(0.34697469746974696, 0.575, 'alcohol <= 9.65\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 0, 4, 0, 0]\nclass = 6'),
#  Text(0.34345434543454345, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.3504950495049505, 0.525, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]\nclass = 6'),
#  Text(0.3645764576457646, 0.575, 'volatile acidity <= 0.375\ngini = 0.508\nsamples = 16\nvalue = [0, 0, 10, 5, 1, 0]\nclass = 5'),
#  Text(0.35753575357535755, 0.525, 'alcohol <= 10.25\ngini = 0.571\nsamples = 7\nvalue = [0, 0, 2, 4, 1, 0]\nclass = 6'),
#  Text(0.35401540154015404, 0.475, 'citric acid <= 0.535\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 2, 1, 1, 0]\nclass = 5'),
#  Text(0.3504950495049505, 0.425, 'residual sugar <= 2.25\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]\nclass = 6'),
#  Text(0.34697469746974696, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.35401540154015404, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.35753575357535755, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 5'),
#  Text(0.36105610561056106, 0.475, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]\nclass = 6'),
#  Text(0.3716171617161716, 0.525, 'chlorides <= 0.209\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 8, 1, 0, 0]\nclass = 5'),
#  Text(0.3680968096809681, 0.475, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]\nclass = 5'),
#  Text(0.37513751375137516, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.3716171617161716, 0.675, 'residual sugar <= 2.7\ngini = 0.5\nsamples = 6\nvalue = [0, 1, 4, 0, 1, 0]\nclass = 5'),
#  Text(0.3680968096809681, 0.625, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]\nclass = 5'),
#  Text(0.37513751375137516, 0.625, 'volatile acidity <= 0.395\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 1, 0]\nclass = 4'),
#  Text(0.3716171617161716, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.3786578657865787, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.5062156215621563, 0.775, 'alcohol <= 10.25\ngini = 0.512\nsamples = 163\nvalue = [1.0, 3.0, 99.0, 56.0, 4.0, 0.0]\nclass = 5'),
#  Text(0.47183718371837186, 0.725, 'alcohol <= 9.05\ngini = 0.496\nsamples = 142\nvalue = [1, 3, 91, 43, 4, 0]\nclass = 5'),
#  Text(0.45126512651265127, 0.675, 'density <= 0.999\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 0, 3, 0, 0]\nclass = 6'),
#  Text(0.44774477447744776, 0.625, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]\nclass = 6'),
#  Text(0.4547854785478548, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]\nclass = 3'),
#  Text(0.4924092409240924, 0.675, 'chlorides <= 0.097\ngini = 0.48\nsamples = 138\nvalue = [0, 3, 91, 40, 4, 0]\nclass = 5'),
#  Text(0.4618261826182618, 0.625, 'volatile acidity <= 0.683\ngini = 0.514\nsamples = 103\nvalue = [0.0, 3.0, 62.0, 36.0, 2.0, 0.0]\nclass = 5'),
#  Text(0.42178217821782177, 0.575, 'fixed acidity <= 6.95\ngini = 0.557\nsamples = 76\nvalue = [0, 3, 39, 32, 2, 0]\nclass = 5'),
#  Text(0.3927392739273927, 0.525, 'alcohol <= 9.9\ngini = 0.368\nsamples = 22\nvalue = [0, 1, 17, 4, 0, 0]\nclass = 5'),
#  Text(0.3821782178217822, 0.475, 'sulphates <= 0.785\ngini = 0.117\nsamples = 16\nvalue = [0, 0, 15, 1, 0, 0]\nclass = 5'),
#  Text(0.3786578657865787, 0.425, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 14, 0, 0, 0]\nclass = 5'),
#  Text(0.3856985698569857, 0.425, 'volatile acidity <= 0.6\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]\nclass = 5'),
#  Text(0.3821782178217822, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.3892189218921892, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.4033003300330033, 0.475, 'sulphates <= 0.625\ngini = 0.611\nsamples = 6\nvalue = [0, 1, 2, 3, 0, 0]\nclass = 6'),
#  Text(0.3997799779977998, 0.425, 'sulphates <= 0.615\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2, 0, 0, 0]\nclass = 5'),
#  Text(0.3962596259625963, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 5'),
#  Text(0.4033003300330033, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.4068206820682068, 0.425, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]\nclass = 6'),
#  Text(0.4508250825082508, 0.525, 'sulphates <= 0.665\ngini = 0.562\nsamples = 54\nvalue = [0, 2, 22, 28, 2, 0]\nclass = 6'),
#  Text(0.43146314631463145, 0.475, 'free sulfur dioxide <= 13.5\ngini = 0.537\nsamples = 38\nvalue = [0.0, 1.0, 21.0, 15.0, 1.0, 0.0]\nclass = 5'),
#  Text(0.4173817381738174, 0.425, 'total sulfur dioxide <= 30.0\ngini = 0.465\nsamples = 20\nvalue = [0, 1, 14, 4, 1, 0]\nclass = 5'),
#  Text(0.41034103410341033, 0.375, 'chlorides <= 0.086\ngini = 0.58\nsamples = 10\nvalue = [0, 0, 5, 4, 1, 0]\nclass = 5'),
#  Text(0.4068206820682068, 0.325, 'fixed acidity <= 7.4\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 1, 4, 1, 0]\nclass = 6'),
#  Text(0.4033003300330033, 0.275, 'total sulfur dioxide <= 23.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]\nclass = 5'),
#  Text(0.3997799779977998, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.4068206820682068, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.41034103410341033, 0.275, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]\nclass = 6'),
#  Text(0.41386138613861384, 0.325, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]\nclass = 5'),
#  Text(0.42442244224422443, 0.375, 'volatile acidity <= 0.665\ngini = 0.18\nsamples = 10\nvalue = [0, 1, 9, 0, 0, 0]\nclass = 5'),
#  Text(0.4209020902090209, 0.325, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]\nclass = 5'),
#  Text(0.42794279427942794, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.44554455445544555, 0.425, 'free sulfur dioxide <= 19.5\ngini = 0.475\nsamples = 18\nvalue = [0, 0, 7, 11, 0, 0]\nclass = 6'),
#  Text(0.43850385038503853, 0.375, 'chlorides <= 0.073\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 1, 8, 0, 0]\nclass = 6'),
#  Text(0.43498349834983496, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.44202420242024204, 0.325, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]\nclass = 6'),
#  Text(0.4525852585258526, 0.375, 'pH <= 3.225\ngini = 0.444\nsamples = 9\nvalue = [0, 0, 6, 3, 0, 0]\nclass = 5'),
#  Text(0.44906490649064906, 0.325, 'density <= 1.0\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]\nclass = 6'),
#  Text(0.44554455445544555, 0.275, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]\nclass = 6'),
#  Text(0.4525852585258526, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.4561056105610561, 0.325, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]\nclass = 5'),
#  Text(0.4701870187018702, 0.475, 'alcohol <= 9.3\ngini = 0.328\nsamples = 16\nvalue = [0, 1, 1, 13, 1, 0]\nclass = 6'),
#  Text(0.46314631463146316, 0.425, 'fixed acidity <= 8.2\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]\nclass = 4'),
#  Text(0.45962596259625965, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.4666666666666667, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.4772277227722772, 0.425, 'density <= 1.001\ngini = 0.133\nsamples = 14\nvalue = [0, 0, 0, 13, 1, 0]\nclass = 6'),
#  Text(0.4737073707370737, 0.375, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 0, 13, 0, 0]\nclass = 6'),
#  Text(0.4807480748074808, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.5018701870187019, 0.575, 'residual sugar <= 3.4\ngini = 0.252\nsamples = 27\nvalue = [0, 0, 23, 4, 0, 0]\nclass = 5'),
#  Text(0.49834983498349833, 0.525, 'chlorides <= 0.093\ngini = 0.147\nsamples = 25\nvalue = [0, 0, 23, 2, 0, 0]\nclass = 5'),
#  Text(0.4948294829482948, 0.475, 'sulphates <= 0.585\ngini = 0.08\nsamples = 24\nvalue = [0, 0, 23, 1, 0, 0]\nclass = 5'),
#  Text(0.4913091309130913, 0.425, 'free sulfur dioxide <= 29.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]\nclass = 5'),
#  Text(0.4877887788778878, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.4948294829482948, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.49834983498349833, 0.425, 'gini = 0.0\nsamples = 22\nvalue = [0, 0, 22, 0, 0, 0]\nclass = 5'),
#  Text(0.5018701870187019, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.5053905390539054, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.522992299229923, 0.625, 'total sulfur dioxide <= 13.5\ngini = 0.297\nsamples = 35\nvalue = [0.0, 0.0, 29.0, 4.0, 2.0, 0.0]\nclass = 5'),
#  Text(0.5159515951595159, 0.575, 'volatile acidity <= 0.665\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]\nclass = 6'),
#  Text(0.5124312431243124, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.5194719471947195, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.53003300330033, 0.575, 'volatile acidity <= 0.903\ngini = 0.219\nsamples = 33\nvalue = [0, 0, 29, 3, 1, 0]\nclass = 5'),
#  Text(0.5265126512651265, 0.525, 'sulphates <= 1.6\ngini = 0.17\nsamples = 32\nvalue = [0, 0, 29, 3, 0, 0]\nclass = 5'),
#  Text(0.522992299229923, 0.475, 'pH <= 2.945\ngini = 0.121\nsamples = 31\nvalue = [0, 0, 29, 2, 0, 0]\nclass = 5'),
#  Text(0.5194719471947195, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.5265126512651265, 0.425, 'density <= 0.996\ngini = 0.064\nsamples = 30\nvalue = [0, 0, 29, 1, 0, 0]\nclass = 5'),
#  Text(0.522992299229923, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.53003300330033, 0.375, 'gini = 0.0\nsamples = 29\nvalue = [0, 0, 29, 0, 0, 0]\nclass = 5'),
#  Text(0.53003300330033, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.5335533553355336, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.5405940594059406, 0.725, 'residual sugar <= 2.15\ngini = 0.472\nsamples = 21\nvalue = [0, 0, 8, 13, 0, 0]\nclass = 6'),
#  Text(0.5335533553355336, 0.675, 'total sulfur dioxide <= 16.5\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 6, 1, 0, 0]\nclass = 5'),
#  Text(0.53003300330033, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.5370737073707371, 0.625, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]\nclass = 5'),
#  Text(0.5476347634763477, 0.675, 'free sulfur dioxide <= 5.25\ngini = 0.245\nsamples = 14\nvalue = [0, 0, 2, 12, 0, 0]\nclass = 6'),
#  Text(0.5441144114411441, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.5511551155115512, 0.625, 'alcohol <= 10.45\ngini = 0.142\nsamples = 13\nvalue = [0, 0, 1, 12, 0, 0]\nclass = 6'),
#  Text(0.5476347634763477, 0.575, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 11, 0, 0]\nclass = 6'),
#  Text(0.5546754675467547, 0.575, 'fixed acidity <= 10.15\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]\nclass = 5'),
#  Text(0.5511551155115512, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.5581958195819582, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.5705170517051705, 0.875, 'residual sugar <= 1.6\ngini = 0.127\nsamples = 90\nvalue = [0, 1, 84, 4, 1, 0]\nclass = 5'),
#  Text(0.566996699669967, 0.825, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.574037403740374, 0.825, 'sulphates <= 1.175\ngini = 0.107\nsamples = 89\nvalue = [0, 0, 84, 4, 1, 0]\nclass = 5'),
#  Text(0.5652365236523652, 0.775, 'volatile acidity <= 0.325\ngini = 0.069\nsamples = 84\nvalue = [0, 0, 81, 2, 1, 0]\nclass = 5'),
#  Text(0.5581958195819582, 0.725, 'fixed acidity <= 7.2\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]\nclass = 5'),
#  Text(0.5546754675467547, 0.675, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.5617161716171617, 0.675, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.5722772277227722, 0.725, 'density <= 0.996\ngini = 0.048\nsamples = 82\nvalue = [0, 0, 80, 2, 0, 0]\nclass = 5'),
#  Text(0.5687568756875687, 0.675, 'alcohol <= 9.85\ngini = 0.346\nsamples = 9\nvalue = [0, 0, 7, 2, 0, 0]\nclass = 5'),
#  Text(0.5652365236523652, 0.625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.5722772277227722, 0.625, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]\nclass = 5'),
#  Text(0.5757975797579759, 0.675, 'gini = 0.0\nsamples = 73\nvalue = [0, 0, 73, 0, 0, 0]\nclass = 5'),
#  Text(0.5828382838283829, 0.775, 'alcohol <= 9.85\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]\nclass = 5'),
#  Text(0.5793179317931794, 0.725, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(0.5863586358635864, 0.725, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.8078795379537954, 0.925, 'alcohol <= 11.55\ngini = 0.638\nsamples = 427\nvalue = [3, 11, 71, 219, 113, 10]\nclass = 6'),
#  Text(0.6994774477447745, 0.875, 'sulphates <= 0.585\ngini = 0.608\nsamples = 259\nvalue = [3, 9, 60, 145, 40, 2]\nclass = 6'),
#  Text(0.645984598459846, 0.825, 'density <= 0.996\ngini = 0.667\nsamples = 64\nvalue = [3, 8, 29, 21, 3, 0]\nclass = 5'),
#  Text(0.6140814081408141, 0.775, 'total sulfur dioxide <= 10.5\ngini = 0.656\nsamples = 37\nvalue = [1, 4, 11, 18, 3, 0]\nclass = 6'),
#  Text(0.5933993399339934, 0.725, 'citric acid <= 0.3\ngini = 0.667\nsamples = 6\nvalue = [1, 1, 0, 1, 3, 0]\nclass = 7'),
#  Text(0.5898789878987899, 0.675, 'alcohol <= 11.05\ngini = 0.667\nsamples = 3\nvalue = [1, 1, 0, 1, 0, 0]\nclass = 3'),
#  Text(0.5863586358635864, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]\nclass = 3'),
#  Text(0.5933993399339934, 0.625, 'alcohol <= 11.3\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]\nclass = 4'),
#  Text(0.5898789878987899, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.5969196919691969, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.5969196919691969, 0.675, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]\nclass = 7'),
#  Text(0.6347634763476347, 0.725, 'pH <= 3.52\ngini = 0.564\nsamples = 31\nvalue = [0, 3, 11, 17, 0, 0]\nclass = 6'),
#  Text(0.6198019801980198, 0.675, 'residual sugar <= 2.35\ngini = 0.486\nsamples = 24\nvalue = [0, 2, 6, 16, 0, 0]\nclass = 6'),
#  Text(0.6074807480748075, 0.625, 'volatile acidity <= 0.935\ngini = 0.29\nsamples = 18\nvalue = [0, 1, 2, 15, 0, 0]\nclass = 6'),
#  Text(0.6039603960396039, 0.575, 'pH <= 3.135\ngini = 0.215\nsamples = 17\nvalue = [0, 1, 1, 15, 0, 0]\nclass = 6'),
#  Text(0.5969196919691969, 0.525, 'density <= 0.994\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]\nclass = 5'),
#  Text(0.5933993399339934, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.6004400440044004, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.611001100110011, 0.525, 'citric acid <= 0.005\ngini = 0.124\nsamples = 15\nvalue = [0, 1, 0, 14, 0, 0]\nclass = 6'),
#  Text(0.6074807480748075, 0.475, 'pH <= 3.36\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]\nclass = 4'),
#  Text(0.6039603960396039, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.611001100110011, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.6145214521452145, 0.475, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 0, 13, 0, 0]\nclass = 6'),
#  Text(0.611001100110011, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.6321232123212321, 0.625, 'residual sugar <= 7.85\ngini = 0.5\nsamples = 6\nvalue = [0, 1, 4, 1, 0, 0]\nclass = 5'),
#  Text(0.6286028602860286, 0.575, 'chlorides <= 0.077\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]\nclass = 5'),
#  Text(0.6250825082508251, 0.525, 'volatile acidity <= 0.635\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]\nclass = 5'),
#  Text(0.6215621562156216, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.6286028602860286, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.6321232123212321, 0.525, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(0.6356435643564357, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.6497249724972497, 0.675, 'volatile acidity <= 0.968\ngini = 0.449\nsamples = 7\nvalue = [0, 1, 5, 1, 0, 0]\nclass = 5'),
#  Text(0.6462046204620462, 0.625, 'density <= 0.996\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]\nclass = 5'),
#  Text(0.6426842684268427, 0.575, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]\nclass = 5'),
#  Text(0.6497249724972497, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.6532453245324532, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.6778877887788779, 0.775, 'citric acid <= 0.11\ngini = 0.516\nsamples = 27\nvalue = [2, 4, 18, 3, 0, 0]\nclass = 5'),
#  Text(0.6708470847084709, 0.725, 'sulphates <= 0.565\ngini = 0.71\nsamples = 13\nvalue = [2, 4, 5, 2, 0, 0]\nclass = 5'),
#  Text(0.6673267326732674, 0.675, 'density <= 0.997\ngini = 0.66\nsamples = 10\nvalue = [2, 1, 5, 2, 0, 0]\nclass = 5'),
#  Text(0.6602860286028602, 0.625, 'citric acid <= 0.06\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 5, 0, 0, 0]\nclass = 5'),
#  Text(0.6567656765676567, 0.575, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]\nclass = 5'),
#  Text(0.6638063806380639, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.6743674367436744, 0.625, 'volatile acidity <= 0.903\ngini = 0.5\nsamples = 4\nvalue = [2, 0, 0, 2, 0, 0]\nclass = 3'),
#  Text(0.6708470847084709, 0.575, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.6778877887788779, 0.575, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0]\nclass = 3'),
#  Text(0.6743674367436744, 0.675, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.6849284928492849, 0.725, 'residual sugar <= 3.525\ngini = 0.133\nsamples = 14\nvalue = [0, 0, 13, 1, 0, 0]\nclass = 5'),
#  Text(0.6814081408140814, 0.675, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0, 0]\nclass = 5'),
#  Text(0.6884488448844884, 0.675, 'volatile acidity <= 0.435\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]\nclass = 5'),
#  Text(0.6849284928492849, 0.625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 5'),
#  Text(0.6919691969196919, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.752970297029703, 0.825, 'volatile acidity <= 0.375\ngini = 0.534\nsamples = 195\nvalue = [0.0, 1.0, 31.0, 124.0, 37.0, 2.0]\nclass = 6'),
#  Text(0.7316831683168317, 0.775, 'fixed acidity <= 11.0\ngini = 0.651\nsamples = 70\nvalue = [0, 0, 13, 31, 24, 2]\nclass = 6'),
#  Text(0.7203520352035203, 0.725, 'total sulfur dioxide <= 56.5\ngini = 0.636\nsamples = 62\nvalue = [0, 0, 12, 31, 17, 2]\nclass = 6'),
#  Text(0.7082508250825083, 0.675, 'chlorides <= 0.058\ngini = 0.589\nsamples = 51\nvalue = [0.0, 0.0, 5.0, 28.0, 16.0, 2.0]\nclass = 6'),
#  Text(0.699009900990099, 0.625, 'density <= 0.994\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 1, 6, 0]\nclass = 7'),
#  Text(0.6954895489548955, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.7025302530253025, 0.575, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]\nclass = 7'),
#  Text(0.7174917491749175, 0.625, 'total sulfur dioxide <= 38.0\ngini = 0.557\nsamples = 44\nvalue = [0, 0, 5, 27, 10, 2]\nclass = 6'),
#  Text(0.7095709570957096, 0.575, 'pH <= 3.385\ngini = 0.66\nsamples = 30\nvalue = [0, 0, 5, 14, 9, 2]\nclass = 6'),
#  Text(0.7060506050605061, 0.525, 'total sulfur dioxide <= 21.5\ngini = 0.609\nsamples = 27\nvalue = [0, 0, 2, 14, 9, 2]\nclass = 6'),
#  Text(0.6937293729372938, 0.475, 'chlorides <= 0.063\ngini = 0.459\nsamples = 14\nvalue = [0, 0, 2, 10, 1, 1]\nclass = 6'),
#  Text(0.6902090209020902, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 5'),
#  Text(0.6972497249724973, 0.425, 'fixed acidity <= 7.85\ngini = 0.292\nsamples = 12\nvalue = [0, 0, 0, 10, 1, 1]\nclass = 6'),
#  Text(0.6937293729372938, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.7007700770077008, 0.375, 'fixed acidity <= 10.65\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 0, 10, 0, 1]\nclass = 6'),
#  Text(0.6972497249724973, 0.325, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]\nclass = 6'),
#  Text(0.7042904290429043, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]\nclass = 8'),
#  Text(0.7183718371837183, 0.475, 'alcohol <= 10.95\ngini = 0.521\nsamples = 13\nvalue = [0, 0, 0, 4, 8, 1]\nclass = 7'),
#  Text(0.7113311331133113, 0.425, 'sulphates <= 0.99\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 0, 4, 2, 0]\nclass = 6'),
#  Text(0.7078107810781078, 0.375, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]\nclass = 6'),
#  Text(0.7148514851485148, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]\nclass = 7'),
#  Text(0.7254125412541255, 0.425, 'alcohol <= 11.35\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 0, 6, 1]\nclass = 7'),
#  Text(0.7218921892189218, 0.375, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]\nclass = 7'),
#  Text(0.728932893289329, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]\nclass = 8'),
#  Text(0.7130913091309131, 0.525, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(0.7254125412541255, 0.575, 'sulphates <= 0.84\ngini = 0.133\nsamples = 14\nvalue = [0, 0, 0, 13, 1, 0]\nclass = 6'),
#  Text(0.7218921892189218, 0.525, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 12, 0, 0]\nclass = 6'),
#  Text(0.728932893289329, 0.525, 'free sulfur dioxide <= 25.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]\nclass = 6'),
#  Text(0.7254125412541255, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
# ...
#  Text(0.7570957095709571, 0.725, 'fixed acidity <= 5.75\ngini = 0.227\nsamples = 71\nvalue = [0.0, 0.0, 7.0, 62.0, 2.0, 0.0]\nclass = 6'),
#  Text(0.7535753575357536, 0.675, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(0.7606160616061606, 0.675, 'alcohol <= 10.575\ngini = 0.164\nsamples = 68\nvalue = [0, 0, 4, 62, 2, 0]\nclass = 6'),
#  Text(0.7570957095709571, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.7641364136413641, 0.625, 'total sulfur dioxide <= 105.5\ngini = 0.14\nsamples = 67\nvalue = [0, 0, 4, 62, 1, 0]\nclass = 6'),
#  Text(0.7606160616061606, 0.575, 'pH <= 3.195\ngini = 0.115\nsamples = 66\nvalue = [0, 0, 3, 62, 1, 0]\nclass = 6'),
#  Text(0.7535753575357536, 0.525, 'sulphates <= 0.82\ngini = 0.571\nsamples = 7\nvalue = [0, 0, 2, 4, 1, 0]\nclass = 6'),
#  Text(0.75005500550055, 0.475, 'sulphates <= 0.795\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 0, 1, 0]\nclass = 5'),
#  Text(0.7465346534653465, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.7535753575357536, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 5'),
#  Text(0.7570957095709571, 0.475, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]\nclass = 6'),
#  Text(0.7676567656765677, 0.525, 'density <= 0.996\ngini = 0.033\nsamples = 59\nvalue = [0, 0, 1, 58, 0, 0]\nclass = 6'),
#  Text(0.7641364136413641, 0.475, 'gini = 0.0\nsamples = 54\nvalue = [0, 0, 0, 54, 0, 0]\nclass = 6'),
#  Text(0.7711771177117712, 0.475, 'sulphates <= 0.695\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]\nclass = 6'),
#  Text(0.7676567656765677, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.7746974697469747, 0.425, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]\nclass = 6'),
#  Text(0.7676567656765677, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.7914191419141914, 0.725, 'citric acid <= 0.12\ngini = 0.587\nsamples = 54\nvalue = [0, 1, 11, 31, 11, 0]\nclass = 6'),
#  Text(0.7782178217821782, 0.675, 'density <= 0.999\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 1, 5, 0]\nclass = 7'),
#  Text(0.7746974697469747, 0.625, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]\nclass = 7'),
#  Text(0.7817381738173818, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.8046204620462046, 0.675, 'residual sugar <= 2.9\ngini = 0.541\nsamples = 48\nvalue = [0, 1, 11, 30, 6, 0]\nclass = 6'),
#  Text(0.7887788778877888, 0.625, 'citric acid <= 0.355\ngini = 0.38\nsamples = 33\nvalue = [0, 0, 7, 25, 1, 0]\nclass = 6'),
#  Text(0.7782178217821782, 0.575, 'citric acid <= 0.255\ngini = 0.579\nsamples = 11\nvalue = [0, 0, 5, 5, 1, 0]\nclass = 5'),
#  Text(0.7746974697469747, 0.525, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]\nclass = 6'),
#  Text(0.7817381738173818, 0.525, 'chlorides <= 0.075\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 0, 1, 0]\nclass = 5'),
#  Text(0.7782178217821782, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.7852585258525853, 0.475, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]\nclass = 5'),
#  Text(0.7993399339933993, 0.575, 'sulphates <= 0.83\ngini = 0.165\nsamples = 22\nvalue = [0, 0, 2, 20, 0, 0]\nclass = 6'),
#  Text(0.7958195819581958, 0.525, 'density <= 0.997\ngini = 0.091\nsamples = 21\nvalue = [0, 0, 1, 20, 0, 0]\nclass = 6'),
#  Text(0.7922992299229923, 0.475, 'density <= 0.997\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]\nclass = 6'),
#  Text(0.7887788778877888, 0.425, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]\nclass = 6'),
#  Text(0.7958195819581958, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.7993399339933993, 0.475, 'gini = 0.0\nsamples = 17\nvalue = [0, 0, 0, 17, 0, 0]\nclass = 6'),
#  Text(0.8028602860286028, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.8204620462046205, 0.625, 'chlorides <= 0.079\ngini = 0.702\nsamples = 15\nvalue = [0, 1, 4, 5, 5, 0]\nclass = 6'),
#  Text(0.8134213421342135, 0.575, 'alcohol <= 10.95\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 4, 1, 0]\nclass = 6'),
#  Text(0.80990099009901, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.816941694169417, 0.525, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]\nclass = 6'),
#  Text(0.8275027502750275, 0.575, 'total sulfur dioxide <= 26.5\ngini = 0.66\nsamples = 10\nvalue = [0, 1, 4, 1, 4, 0]\nclass = 5'),
#  Text(0.823982398239824, 0.525, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(0.831023102310231, 0.525, 'sulphates <= 0.795\ngini = 0.612\nsamples = 7\nvalue = [0, 1, 1, 1, 4, 0]\nclass = 7'),
#  Text(0.823982398239824, 0.475, 'citric acid <= 0.305\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 0, 0, 4, 0]\nclass = 7'),
#  Text(0.8204620462046205, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.8275027502750275, 0.425, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]\nclass = 7'),
#  Text(0.838063806380638, 0.475, 'free sulfur dioxide <= 28.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]\nclass = 5'),
#  Text(0.8345434543454345, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.8415841584158416, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.9162816281628163, 0.875, 'sulphates <= 0.685\ngini = 0.61\nsamples = 168\nvalue = [0, 2, 11, 74, 73, 8]\nclass = 6'),
#  Text(0.8686468646864687, 0.825, 'total sulfur dioxide <= 14.5\ngini = 0.569\nsamples = 90\nvalue = [0, 2, 10, 53, 24, 1]\nclass = 6'),
#  Text(0.8415841584158416, 0.775, 'sulphates <= 0.545\ngini = 0.521\nsamples = 24\nvalue = [0, 1, 1, 7, 15, 0]\nclass = 7'),
#  Text(0.8345434543454345, 0.725, 'sulphates <= 0.51\ngini = 0.449\nsamples = 7\nvalue = [0, 0, 1, 5, 1, 0]\nclass = 6'),
#  Text(0.831023102310231, 0.675, 'density <= 0.997\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]\nclass = 5'),
#  Text(0.8275027502750275, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.8345434543454345, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.838063806380638, 0.675, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]\nclass = 6'),
#  Text(0.8486248624862486, 0.725, 'chlorides <= 0.051\ngini = 0.304\nsamples = 17\nvalue = [0, 1, 0, 2, 14, 0]\nclass = 7'),
#  Text(0.8451045104510451, 0.675, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.8521452145214522, 0.675, 'volatile acidity <= 0.7\ngini = 0.219\nsamples = 16\nvalue = [0, 0, 0, 2, 14, 0]\nclass = 7'),
#  Text(0.8486248624862486, 0.625, 'density <= 0.997\ngini = 0.124\nsamples = 15\nvalue = [0, 0, 0, 1, 14, 0]\nclass = 7'),
#  Text(0.8451045104510451, 0.575, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 0, 0, 13, 0]\nclass = 7'),
#  Text(0.8521452145214522, 0.575, 'fixed acidity <= 9.25\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]\nclass = 6'),
#  Text(0.8486248624862486, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.8556655665566557, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.8556655665566557, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.8957095709570957, 0.775, 'free sulfur dioxide <= 31.5\ngini = 0.477\nsamples = 66\nvalue = [0, 1, 9, 46, 9, 1]\nclass = 6'),
#  Text(0.8864686468646865, 0.725, 'alcohol <= 12.85\ngini = 0.413\nsamples = 59\nvalue = [0, 1, 9, 44, 5, 0]\nclass = 6'),
#  Text(0.8785478547854786, 0.675, 'total sulfur dioxide <= 90.0\ngini = 0.311\nsamples = 50\nvalue = [0, 0, 5, 41, 4, 0]\nclass = 6'),
#  Text(0.8750275027502751, 0.625, 'volatile acidity <= 0.553\ngini = 0.286\nsamples = 49\nvalue = [0, 0, 5, 41, 3, 0]\nclass = 6'),
#  Text(0.8662266226622662, 0.575, 'total sulfur dioxide <= 24.5\ngini = 0.124\nsamples = 30\nvalue = [0, 0, 0, 28, 2, 0]\nclass = 6'),
#  Text(0.8627062706270627, 0.525, 'free sulfur dioxide <= 10.5\ngini = 0.375\nsamples = 8\nvalue = [0, 0, 0, 6, 2, 0]\nclass = 6'),
#  Text(0.8591859185918592, 0.475, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]\nclass = 6'),
#  Text(0.8662266226622662, 0.475, 'free sulfur dioxide <= 11.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]\nclass = 7'),
#  Text(0.8627062706270627, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]\nclass = 7'),
#  Text(0.8697469746974698, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.8697469746974698, 0.525, 'gini = 0.0\nsamples = 22\nvalue = [0, 0, 0, 22, 0, 0]\nclass = 6'),
#  Text(0.8838283828382838, 0.575, 'chlorides <= 0.058\ngini = 0.46\nsamples = 19\nvalue = [0, 0, 5, 13, 1, 0]\nclass = 6'),
#  Text(0.8767876787678768, 0.525, 'free sulfur dioxide <= 14.5\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]\nclass = 5'),
#  Text(0.8732673267326733, 0.475, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(0.8803080308030803, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.8908690869086908, 0.525, 'volatile acidity <= 0.57\ngini = 0.338\nsamples = 15\nvalue = [0, 0, 2, 12, 1, 0]\nclass = 6'),
#  Text(0.8873487348734873, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.8943894389438944, 0.475, 'total sulfur dioxide <= 51.0\ngini = 0.245\nsamples = 14\nvalue = [0, 0, 2, 12, 0, 0]\nclass = 6'),
#  Text(0.8873487348734873, 0.425, 'residual sugar <= 2.45\ngini = 0.153\nsamples = 12\nvalue = [0, 0, 1, 11, 0, 0]\nclass = 6'),
#  Text(0.8838283828382838, 0.375, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]\nclass = 6'),
#  Text(0.8908690869086908, 0.375, 'chlorides <= 0.078\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]\nclass = 5'),
#  Text(0.8873487348734873, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.8943894389438944, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.9014301430143015, 0.425, 'volatile acidity <= 0.83\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]\nclass = 5'),
#  Text(0.897909790979098, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.904950495049505, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.8820682068206821, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.8943894389438944, 0.675, 'citric acid <= 0.12\ngini = 0.667\nsamples = 9\nvalue = [0, 1, 4, 3, 1, 0]\nclass = 5'),
#  Text(0.8908690869086908, 0.625, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]\nclass = 5'),
#  Text(0.897909790979098, 0.625, 'fixed acidity <= 4.65\ngini = 0.56\nsamples = 5\nvalue = [0, 1, 0, 3, 1, 0]\nclass = 6'),
#  Text(0.8943894389438944, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.9014301430143015, 0.575, 'volatile acidity <= 0.385\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]\nclass = 6'),
#  Text(0.897909790979098, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.904950495049505, 0.525, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]\nclass = 6'),
#  Text(0.904950495049505, 0.725, 'fixed acidity <= 7.95\ngini = 0.571\nsamples = 7\nvalue = [0, 0, 0, 2, 4, 1]\nclass = 7'),
#  Text(0.9014301430143015, 0.675, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]\nclass = 7'),
#  Text(0.9084708470847085, 0.675, 'alcohol <= 12.25\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 0, 1]\nclass = 6'),
#  Text(0.904950495049505, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]\nclass = 8'),
#  Text(0.911991199119912, 0.625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.9639163916391639, 0.825, 'free sulfur dioxide <= 18.5\ngini = 0.525\nsamples = 78\nvalue = [0, 0, 1, 21, 49, 7]\nclass = 7'),
#  Text(0.9454345434543454, 0.775, 'free sulfur dioxide <= 8.0\ngini = 0.432\nsamples = 55\nvalue = [0, 0, 0, 9, 40, 6]\nclass = 7'),
#  Text(0.9295929592959296, 0.725, 'volatile acidity <= 0.37\ngini = 0.62\nsamples = 23\nvalue = [0, 0, 0, 8, 11, 4]\nclass = 7'),
#  Text(0.9225522552255225, 0.675, 'residual sugar <= 4.6\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 0, 0, 8, 1]\nclass = 7'),
#  Text(0.919031903190319, 0.625, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 0, 8, 0]\nclass = 7'),
#  Text(0.926072607260726, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]\nclass = 8'),
#  Text(0.9366336633663367, 0.675, 'sulphates <= 0.695\ngini = 0.582\nsamples = 14\nvalue = [0, 0, 0, 8, 3, 3]\nclass = 6'),
#  Text(0.9331133113311331, 0.625, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 3]\nclass = 8'),
#  Text(0.9401540154015402, 0.625, 'volatile acidity <= 0.515\ngini = 0.397\nsamples = 11\nvalue = [0, 0, 0, 8, 3, 0]\nclass = 6'),
#  Text(0.9366336633663367, 0.575, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]\nclass = 6'),
#  Text(0.9436743674367437, 0.575, 'volatile acidity <= 0.575\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 0, 3, 3, 0]\nclass = 6'),
#  Text(0.9401540154015402, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]\nclass = 7'),
#  Text(0.9471947194719472, 0.525, 'volatile acidity <= 0.66\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]\nclass = 6'),
#  Text(0.9436743674367437, 0.475, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]\nclass = 6'),
#  Text(0.9507150715071507, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.9612761276127613, 0.725, 'chlorides <= 0.155\ngini = 0.174\nsamples = 32\nvalue = [0, 0, 0, 1, 29, 2]\nclass = 7'),
#  Text(0.9577557755775578, 0.675, 'volatile acidity <= 0.833\ngini = 0.121\nsamples = 31\nvalue = [0, 0, 0, 0, 29, 2]\nclass = 7'),
#  Text(0.9542354235423542, 0.625, 'residual sugar <= 3.45\ngini = 0.064\nsamples = 30\nvalue = [0, 0, 0, 0, 29, 1]\nclass = 7'),
#  Text(0.9507150715071507, 0.575, 'gini = 0.0\nsamples = 27\nvalue = [0, 0, 0, 0, 27, 0]\nclass = 7'),
#  Text(0.9577557755775578, 0.575, 'sulphates <= 0.825\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 0, 2, 1]\nclass = 7'),
#  Text(0.9542354235423542, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]\nclass = 7'),
#  Text(0.9612761276127613, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]\nclass = 8'),
#  Text(0.9612761276127613, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]\nclass = 8'),
#  Text(0.9647964796479648, 0.675, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.9823982398239824, 0.775, 'pH <= 3.36\ngini = 0.571\nsamples = 23\nvalue = [0, 0, 1, 12, 9, 1]\nclass = 6'),
#  Text(0.9753575357535753, 0.725, 'chlorides <= 0.087\ngini = 0.314\nsamples = 11\nvalue = [0, 0, 1, 1, 9, 0]\nclass = 7'),
#  Text(0.9718371837183718, 0.675, 'free sulfur dioxide <= 40.5\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 0, 1, 9, 0]\nclass = 7'),
#  Text(0.9683168316831683, 0.625, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 0, 8, 0]\nclass = 7'),
#  Text(0.9753575357535753, 0.625, 'total sulfur dioxide <= 81.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]\nclass = 6'),
#  Text(0.9718371837183718, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.9788778877887789, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.9788778877887789, 0.675, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.9894389438943895, 0.725, 'free sulfur dioxide <= 30.5\ngini = 0.153\nsamples = 12\nvalue = [0, 0, 0, 11, 0, 1]\nclass = 6'),
#  Text(0.985918591859186, 0.675, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]\nclass = 6'),
#  Text(0.992959295929593, 0.675, 'free sulfur dioxide <= 36.0\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 0, 1]\nclass = 6'),
#  Text(0.9894389438943895, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]\nclass = 8'),
#  Text(0.9964796479647965, 0.625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6')]

# %%
plt.show()
